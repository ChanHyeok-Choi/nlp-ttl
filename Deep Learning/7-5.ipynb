# %% [markdown]
# # 역전파 이해하기: BackPropagation

# %% [markdown]
# ## 1. 인공 신경망의 이해: Neural Network Overview
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. 순전파: Forward Propagation
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# * 최종적으로 예측값과 실체값의 오차를 계산해줘야 합니다.
#
#     ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## 3. 역전파 1단계: BackPropagation Step 1
# * 출력층과 N층 사이의 가중치를 업데이트하는 단계를 역전파 1단계, 그리고 N층과 N층의 이전층 사이의 가중치를 업데이트 하는 단계를 역전파 2단계라고 해봅시다.
#
#     ![image.png](attachment:image.png)
# * 1단계에서 업데이트해야 할 가중치는 w5~8 총 4개입니다.
#
#     ![image-2.png](attachment:image-2.png)
# * E_total은 앞서 순전파를 진행하고 계산했던 전체 오차값입니다.
#
#     ![image-3.png](attachment:image-3.png)
#     ![image-4.png](attachment:image-4.png)
# * 시그모이드의 함수의 미분은 f(x)*(1-f(x))입니다.
#
#     ![image-5.png](attachment:image-5.png)
# * 마지막 세번째 항은 h1의 값과 동일합니다.
#
#     ![image-6.png](attachment:image-6.png)
# * 이제 이 값을 모두 곱해주면 됩니다.
#
#     ![image-7.png](attachment:image-7.png)
# * 가중치 업데이트
#
#     ![image-8.png](attachment:image-8.png)
#     ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 4. 역전파 2단계: BackPropagation Step 2
# ![image.png](attachment:image.png)
# * 이젠 w1~4 가중치를 계산해야 합니다.
#
#     ![image-2.png](attachment:image-2.png)
#     ![image-3.png](attachment:image-3.png)
#     ![image-4.png](attachment:image-4.png)
#     ![image-5.png](attachment:image-5.png)
#     ![image-6.png](attachment:image-6.png)
#     ![image-7.png](attachment:image-7.png)
# * 가중치 업데이트
#
#     ![image-8.png](attachment:image-8.png)
#     ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 5. 결과 확인
# ![image.png](attachment:image.png)
# * 기존 오차가 0.02397190였으므로 1번의 역전파로 오차가 감소한 것을 확인할 수 있습니다.
