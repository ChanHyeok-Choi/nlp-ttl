# %% [markdown]
# # 게이트 순환 유닛: Gated Recurrent Unit, GRU
# - LSTM의 장기 의존성 문제에 대한 해결책을 유지하면서, 은닉 상태를 업데이트하는 계산을 줄였습니다.
# - 다시 말해서, GRU는 성능은 LSTM과 유사하면서 복잡했던 LSTM의 구조를 간단화 시켰습니다.

# %% [markdown]
# ## 1. GRU: Grated Recurrent Unit
# - LSTM에선 출력, 입력, 삭제 게이트라는 3개의 게이트가 존재했던 반면, GRU에선 업데이트 게이트와 리셋 게이트 두 가지 게이트만 존재합니다.
#
#     ![image.png](attachment:image.png)
# - 경험적으로 데이터 양이 적을 땐 매개변수의 양이 적은 GRU가 조금 더 낫고, 데이터 양이 많으면 LSTM이 더 낫다고도 합니다.

# %% [markdown]
# ## 2. 케라스에서의 GRU

# %%
model.add(GRU(hidden_size, input_shape=(timesteps, input_dim)))
